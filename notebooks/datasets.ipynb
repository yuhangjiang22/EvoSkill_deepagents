# %%
import pandas as pd
from pathlib import Path
import os

train_df = pd.read_csv("../.dataset/new_runs_evolved/train_set.csv")

# %%
train_df.head()

# %%
train_df.category.value_counts(normalize=True)
