# %%
from src.evaluation import score_answer
import pickle as pkl
with open('../results/full_run_new.pkl', 'rb') as f:
    data = pkl.load(f)

# %%
eval_set_original = {
    'question': [],
    'index': [],
    'predicted': [],
    'ground_truth': [],
    'score_0.05': [],
    'score_0.01': [],
    'score_0.1': [],
    'score_0.0': [],
    'score_0.025': [],
    "final_score": []
}

# %%
for example in data:
    try:
        question = example.question
        index = example.index
        ground_truth = example.ground_truth
        predicted = example.trace.output.final_answer
        final_score = 0.0
        for tolerance in [0.05, 0.01, 0.1, 0.0, 0.025]:
            score = score_answer(ground_truth=ground_truth, predicted=predicted, tolerance=tolerance)
            final_score += score
            eval_set_original[f'score_{tolerance}'].append(score)
        final_score /= 5
        eval_set_original['final_score'].append(final_score)
        eval_set_original['question'].append(question)
        eval_set_original['index'].append(index)
        eval_set_original['ground_truth'].append(ground_truth)
        eval_set_original['predicted'].append(predicted)
    except Exception as e:
        print(f"Error processing example {index}: {e}")
        continue
# Out:
# Error processing example 153: 'NoneType' object has no attribute 'final_answer'
# Error processing example 36: 'NoneType' object has no attribute 'final_answer'
# Error processing example 209: 'NoneType' object has no attribute 'final_answer'
# Error processing example 50: 'NoneType' object has no attribute 'final_answer'

# %%
import pandas as pd
original_df = pd.DataFrame(eval_set_original)

# %%
print(f"0 tolerance score: {original_df['score_0.0'].mean().item()}")
print(f"final score averaged: {original_df['final_score'].mean().item()}")
# Out:
# 0 tolerance score: 0.6115702479338843
# final score averaged: 0.73801652892562

# %%
from src.evaluation import score_answer
import pickle as pkl
with open('../results/improved_eval.pkl', 'rb') as f:
    data = pkl.load(f)

# %%
eval_set_original = {
    'question': [],
    'index': [],
    'predicted': [],
    'ground_truth': [],
    'score_0.05': [],
    'score_0.01': [],
    'score_0.1': [],
    'score_0.0': [],
    'score_0.025': [],
    "final_score": []
}

# %%
for example in data:
    try:
        question = example.question
        index = example.index
        ground_truth = example.ground_truth
        predicted = example.trace.output.final_answer
        final_score = 0.0
        for tolerance in [0.05, 0.01, 0.1, 0.0, 0.025]:
            score = score_answer(ground_truth=ground_truth, predicted=predicted, tolerance=tolerance)
            final_score += score
            eval_set_original[f'score_{tolerance}'].append(score)
        final_score /= 5
        eval_set_original['final_score'].append(final_score)
        eval_set_original['question'].append(question)
        eval_set_original['index'].append(index)
        eval_set_original['ground_truth'].append(ground_truth)
        eval_set_original['predicted'].append(predicted)
    except Exception as e:
        print(f"Error processing example {index}: {e}")
        continue
# Out:
# Error processing example 29: 'NoneType' object has no attribute 'final_answer'
# Error processing example 113: 'NoneType' object has no attribute 'output'
# Error processing example 8: 'NoneType' object has no attribute 'final_answer'
# Error processing example 215: 'NoneType' object has no attribute 'final_answer'
# Error processing example 22: 'NoneType' object has no attribute 'output'
# Error processing example 25: 'NoneType' object has no attribute 'final_answer'
# Error processing example 103: 'NoneType' object has no attribute 'final_answer'
# Error processing example 181: 'NoneType' object has no attribute 'final_answer'
# Error processing example 220: 'NoneType' object has no attribute 'final_answer'
# Error processing example 65: 'NoneType' object has no attribute 'final_answer'
# Error processing example 143: 'NoneType' object has no attribute 'final_answer'
# Error processing example 221: 'NoneType' object has no attribute 'final_answer'
# Error processing example 24: 'NoneType' object has no attribute 'final_answer'
# Error processing example 26: 'NoneType' object has no attribute 'final_answer'
# Error processing example 104: 'NoneType' object has no attribute 'final_answer'
# Error processing example 27: 'NoneType' object has no attribute 'final_answer'
# Error processing example 182: 'NoneType' object has no attribute 'final_answer'
# Error processing example 142: 'NoneType' object has no attribute 'final_answer'

# %%
improved_df = pd.DataFrame(eval_set_original)

# %%
print(f"0 tolerance score: {improved_df['score_0.0'].mean().item()}")
print(f"final score averaged: {improved_df['final_score'].mean().item()}")
# Out:
# 0 tolerance score: 0.6491228070175439
# final score averaged: 0.76140350877193
