# %%
import pandas as pd
from pathlib import Path
import os

# %%
dataset_path = Path("~/mnt/shared-resources-sentient-research/salah_resources/datasets/officeqa/")
data_file = "officeqa.csv"
data = pd.read_csv(os.path.join(dataset_path, data_file))

# %%
import pickle

# %%
with open('../results/trial_run.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data[0].ground_truth
# Out:
# '103,375'

# %%
data[0].trace.output.final_answer
# Out:
# "The highest amount of U.S. claims owed by a country (excluding territories and regional aggregates) in calendar year 1995 was **Japan** with **$109,821 million** (recorded in June 1995).\n\nThis data comes from the U.S. Treasury International Capital (TIC) System, which tracks U.S. banking claims on foreigners by country. Japan's claims peaked at $109,821 million in Q2 1995, surpassing the United Kingdom which had the second-highest claims at $103,375 million (December 1995)."
